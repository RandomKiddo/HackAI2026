# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("palbha/cmapss-jet-engine-simulated-data")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 1.0.0)
# Path to dataset files: /Users/jacobbalek/.cache/kagglehub/datasets/palbha/cmapss-jet-engine-simulated-data/versions/1

# %% [markdown]
# Data structures:
#
# 1)	unit number
# 2)	time, in cycles
# 3)	operational setting 1
# 4)	operational setting 2
# 5)	operational setting 3
# 6)	sensor measurement  1
# 7)	sensor measurement  2
# ...
# 26)	sensor measurement  26

# %%
# Test imported data
import pandas as pd

# RUL use to 
FD001 = "/test_FD001.txt"

FD1df = pd.read_csv(path + FD001)

print(FD1df.columns)
# Out:
# Index(['1 1 0.0023 0.0003 100.0 518.67 643.02 1585.29 1398.21 14.62 21.61 553.90 2388.04 9050.17 1.30 47.20 521.72 2388.03 8125.55 8.4052 0.03 392 2388 100.00 38.86 23.3735  '], dtype='object')
